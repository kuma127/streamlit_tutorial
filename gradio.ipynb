# %%
# %load_ext gradio

# %%
import gradio as gr

# %%
def greet(name, intensity):
    return "Hello " * intensity + name + "!"

demo = gr.Interface(
    fn=greet,
    inputs=["text", gr.Slider(value=2, minimum=1, maximum=10)],
    outputs=["text"]
)

# %%
import pandas as pd

# %%
test = pd.read_html('https://www.fangraphs.com/leaders/major-league?pos=all&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bstats=bat&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Blg=all&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bqual=0&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Btype=8&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bseason=2023&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bmonth=0&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bseason1=2023&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bind=0&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bteam=0%2Cts&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Brost=&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bage=&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bfilter=&amp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bamp%3Bplayers=0&pagenum=1&pageitems=2000000000')

# %%
test[7]
# Out:
#        #               Name   Team  GG - Games Played  \
# 0      1   Ronald Acuña Jr.    ATL                159
# 1      2       Mookie Betts    LAD                152
# 2      3    Freddie Freeman    LAD                161
# 3      4         Matt Olson    ATL                162
# 4      5      Shohei Ohtani    LAA                135
# ..   ...                ...    ...                ...
# 128  129       Tim Anderson    CHW                123
# 129  130         José Abreu    HOU                141
# 130  131   Tyler Stephenson    CIN                142
# 131  132  Enrique Hernández  2 Tms                140
# 132  133   Jurickson Profar  2 Tms                125
#
#      PAPA - Plate Appearances  HRHR - Home Runs  RR - Runs  \
# 0                         735                41        149
# 1                         693                39        126
# 2                         730                29        131
# 3                         720                54        127
# ...

# %%
# %%blocks
#
# styler = test[7].style.highlight_max(color = 'lightgreen', axis = 0)
#
# with gr.Blocks() as demo:
#     gr.DataFrame(styler)
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
